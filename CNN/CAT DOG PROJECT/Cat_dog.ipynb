# %%
import tensorflow as tf

train_dataset = tf.keras.utils.image_dataset_from_directory(
    r"D:\PROJECTS\DEEP LEARNING PROJECT\CNN\CAT DOG PROJECT\train",
    image_size=(150, 150),
    batch_size=32,
    label_mode="binary"
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    r"D:\PROJECTS\DEEP LEARNING PROJECT\CNN\CAT DOG PROJECT\val",
    image_size=(150, 150),
    batch_size=32,
    label_mode="binary"
)
# Out:
# Found 275 files belonging to 2 classes.
# Found 70 files belonging to 2 classes.

# %%
train_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>

# %%
train_dataset=train_dataset.map(
    lambda x,y:(x/255, y)
)
val_dataset=val_dataset.map(
    lambda x,y: (x/255, y)
)

# %%
import tensorflow as tf 
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D, Conv2D
from tensorflow.keras.models import Sequential

# %%
model=Sequential()
model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(150, 150, 3)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# d:\PROJECTS\DEEP LEARNING PROJECT\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=25
)
# Out:
# Epoch 1/25
# d:\PROJECTS\DEEP LEARNING PROJECT\.venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 624ms/step - accuracy: 0.5745 - loss: 1.0576 - val_accuracy: 0.6571 - val_loss: 0.6406
# Epoch 2/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 514ms/step - accuracy: 0.6545 - loss: 0.6446 - val_accuracy: 0.6571 - val_loss: 0.6866
# Epoch 3/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 475ms/step - accuracy: 0.6545 - loss: 0.6393 - val_accuracy: 0.6571 - val_loss: 0.6374
# Epoch 4/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 425ms/step - accuracy: 0.6545 - loss: 0.6021 - val_accuracy: 0.6571 - val_loss: 0.6390
# Epoch 5/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 448ms/step - accuracy: 0.6764 - loss: 0.5599 - val_accuracy: 0.6286 - val_loss: 0.6434
# Epoch 6/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 447ms/step - accuracy: 0.7891 - loss: 0.5048 - val_accuracy: 0.6286 - val_loss: 0.6596
# Epoch 7/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 438ms/step - accuracy: 0.8618 - loss: 0.3850 - val_accuracy: 0.6571 - val_loss: 1.2712
# Epoch 8/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 497ms/step - accuracy: 0.8582 - loss: 0.3985 - val_accuracy: 0.6143 - val_loss: 0.7866
# Epoch 9/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step - accuracy: 0.8982 - loss: 0.2468 - val_accuracy: 0.6429 - val_loss: 0.9368
# Epoch 10/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 448ms/step - accuracy: 0.9455 - loss: 0.1459 - val_accuracy: 0.6429 - val_loss: 0.9994
# Epoch 11/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 478ms/step - accuracy: 0.9709 - loss: 0.0953 - val_accuracy: 0.4857 - val_loss: 1.5166
# Epoch 12/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 416ms/step - accuracy: 0.9782 - loss: 0.0873 - val_accuracy: 0.6000 - val_loss: 1.0997
# Epoch 13/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 526ms/step - accuracy: 0.9745 - loss: 0.0668 - val_accuracy: 0.4857 - val_loss: 1.4655
# Epoch 14/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 574ms/step - accuracy: 0.9673 - loss: 0.0839 - val_accuracy: 0.5857 - val_loss: 1.2159
# Epoch 15/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 539ms/step - accuracy: 0.9964 - loss: 0.0224 - val_accuracy: 0.6000 - val_loss: 1.6670
# Epoch 16/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 570ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.6286 - val_loss: 2.0677
# Epoch 17/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 587ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.6286 - val_loss: 2.1741
# Epoch 18/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 583ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.6286 - val_loss: 2.3338
# Epoch 19/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 631ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6286 - val_loss: 2.4090
# Epoch 20/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 494ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.6571 - val_loss: 2.3872
# Epoch 21/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 475ms/step - accuracy: 1.0000 - loss: 6.8340e-04 - val_accuracy: 0.6429 - val_loss: 2.5485
# Epoch 22/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 568ms/step - accuracy: 1.0000 - loss: 5.2429e-04 - val_accuracy: 0.6429 - val_loss: 2.5847
# Epoch 23/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 590ms/step - accuracy: 1.0000 - loss: 3.8608e-04 - val_accuracy: 0.6571 - val_loss: 2.5622
# Epoch 24/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 511ms/step - accuracy: 1.0000 - loss: 3.4132e-04 - val_accuracy: 0.6571 - val_loss: 2.5877
# Epoch 25/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 551ms/step - accuracy: 1.0000 - loss: 2.9579e-04 - val_accuracy: 0.6571 - val_loss: 2.6310

# %%
model.save('cat_dog_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
