# %%
import tensorflow as ft 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import datetime
import pickle

# %%
from tensorflow.keras.models import load_model

model = load_model("model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
with open('label_encoder_gender.pkl', 'rb')as file:
    label_encoder_gender=pickle.load(file)

with open('onehot_encoder_geo.pkl', 'rb')as file:
    onehot_encoder_geo=pickle.load(file)

with open('scaler.pkl', 'rb')as file:
    scaler=pickle.load(file)

# %%
input_data={
    'CreditScore': 619,
    'Geography':'Germany',
    'Gender':'Female',
    'Age':42,
    'Tenure':2,
    'Balance':0.00,
    'NumOfProducts':1,
    'HasCrCard':1,
    'IsActiveMember':1,
    'EstimatedSalary':101348.88
}

# %%
geo_encoded=onehot_encoder_geo.transform([[input_data['Geography']]]).toarray()
import pandas as pd
# Out:
# d:\PROJECTS\DEEP LEARNING PROJECT\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
geo_encoded_df=pd.DataFrame(geo_encoded, columns=onehot_encoder_geo.get_feature_names_out(['Geography']))
input_data['Gender']=label_encoder_gender.transform([input_data['Gender']])[0]

# %%
input_df=pd.DataFrame([input_data])
input_df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          619   Germany       0   42       2      0.0              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88

# %%
input_data=pd.concat([input_df.drop('Geography', axis=1), geo_encoded_df], axis=1)

# %%
input_scaled=scaler.transform(input_data)

# %%
input_data
# Out:
#    CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2      0.0              1          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1        101348.88               0.0                1.0
#
#    Geography_Spain
# 0              0.0

# %%
prediction=model.predict(input_scaled)
prediction_proba=prediction[0][0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
prediction_proba
# Out:
# np.float32(0.4561784)
