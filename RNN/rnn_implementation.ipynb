# %%
import numpy as np 
import tensorflow as tf 
from tensorflow.keras.datasets import imdb 
from tensorflow.keras.layers import Dense, Embedding, SimpleRNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import sequence

# %%
max_features=10000
(x_train, y_train), (x_test, y_test)=imdb.load_data(num_words=max_features)

# %%
sample_review=x_train[0]
sample_label=y_train[0]

# %%
index_words=imdb.get_word_index()

# %%
reversed_index={value: key for key, value in index_words.items()}

# %%
decoded_review=' '.join([reversed_index.get(i-3, '?')for i in sample_review])

# %%
max_len=500

# %%
x_train=sequence.pad_sequences(x_train, maxlen=max_len)
x_test=sequence.pad_sequences(x_test, maxlen=max_len)

# %%
model=Sequential()
model.add(Embedding(max_features, 128, input_length=max_len))
model.add(SimpleRNN(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# d:\PROJECTS\DEEP LEARNING PROJECT\.venv\Lib\site-packages\keras\src\layers\core\embedding.py:123: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
from tensorflow.keras.callbacks import EarlyStopping
earlystopping=EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(
    x_train,y_train, epochs=15, batch_size=32,
    validation_split=0.2,
    callbacks=[earlystopping]
)
# Out:
# Epoch 1/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 93s 145ms/step - accuracy: 0.6715 - loss: 8.9400 - val_accuracy: 0.7352 - val_loss: 0.5360
# Epoch 2/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 90s 144ms/step - accuracy: 0.8107 - loss: 0.4256 - val_accuracy: 0.7318 - val_loss: 0.5177
# Epoch 3/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.7681 - loss: 1787.5314 - val_accuracy: 0.7094 - val_loss: 0.5594
# Epoch 4/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 124ms/step - accuracy: 0.7718 - loss: 0.5284 - val_accuracy: 0.7172 - val_loss: 0.5413
# Epoch 5/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 136ms/step - accuracy: 0.8160 - loss: 0.4108 - val_accuracy: 0.7582 - val_loss: 0.4939
# Epoch 6/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.8801 - loss: 0.2916 - val_accuracy: 0.8140 - val_loss: 0.4165
# Epoch 7/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.9117 - loss: 0.2221 - val_accuracy: 0.8318 - val_loss: 0.4113
# Epoch 8/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 129ms/step - accuracy: 0.9327 - loss: 0.1797 - val_accuracy: 0.8114 - val_loss: 0.4439
# Epoch 9/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.9452 - loss: 0.1535 - val_accuracy: 0.8298 - val_loss: 0.4499
# Epoch 10/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 128ms/step - accuracy: 0.9548 - loss: 0.1314 - val_accuracy: 0.8234 - val_loss: 0.4691
# Epoch 11/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 92s 147ms/step - accuracy: 0.9623 - loss: 0.1128 - val_accuracy: 0.8322 - val_loss: 0.5307
# Epoch 12/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 96s 153ms/step - accuracy: 0.9647 - loss: 0.1030 - val_accuracy: 0.8248 - val_loss: 0.5283
# Epoch 13/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 98s 157ms/step - accuracy: 0.9714 - loss: 0.0901 - val_accuracy: 0.8278 - val_loss: 0.5181
# Epoch 14/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 93s 148ms/step - accuracy: 0.9732 - loss: 0.0787 - val_accuracy: 0.8284 - val_loss: 0.5780
# Epoch 15/15
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 90s 144ms/step - accuracy: 0.9792 - loss: 0.0639 - val_accuracy: 0.8302 - val_loss: 0.6549

# %%
prediction=model.predict(x_test)
print(prediction)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 34ms/step
# [[0.12761588]
#  [0.9875394 ]
#  [0.70874065]
#  ...
#  [0.07158639]
#  [0.02213632]
#  [0.26944056]]

# %%
prediction[0]
# Out:
# array([0.12761588], dtype=float32)
